# %% [markdown]
# <h1><center>PRODIGY INFOTECH - DATA SCIENCE INTERNSHIP</center></h1>

# %% [markdown]
# <h2 align="right">~ Ashish Ransing</h2>

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### TASK - 2 : Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore") #Never display warnings which match

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Loading Dataset

# %%
titanic_data = pd.read_csv('Titanic_dataset.csv')

# %% [markdown]
# ### Exploring the Data

# %%
df = pd.DataFrame(titanic_data)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### Handling Missing Data

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Filling missing values of 'AGE' column with the median and removing 'Cabin' column due to excess missing values
df['Age'].fillna(df['Age'].median(),inplace = True)
df.drop('Cabin',axis = 1,inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
#Removing rows with missing values in specific column('Embarked')
df.dropna(subset = ['Embarked'],inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Performing EDA and Data Visualization

# %%
#Exploring Distribution of target variable 'Survived'
sns.countplot(x='Survived', palette=['red', 'green'], edgecolor='black', data=df)
plt.show()

# %%
#Exploring Relationship between variables ('Survived' vs 'Sex')
sns.countplot(x = 'Survived', hue = 'Sex', palette = 'Set2', edgecolor = 'black', data = df )
plt.show()

# %%
sns.catplot(x = 'Survived', col = 'Sex', palette = 'Set2', edgecolor = 'black', kind = 'count', data = df)
plt.show()

# %%
#Checking the exact count of males and females survived
df.groupby(['Sex']).Survived.sum()
# Out:
# Sex
# female    231
# male      109
# Name: Survived, dtype: int64

# %%
sns.countplot(x = 'Survived', hue = 'Pclass',palette = 'Set1', data = df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.violinplot(x = 'Sex', y = 'Age', hue = 'Survived' ,palette = ['red', 'green'], data = df , split = True)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.countplot(x = 'SibSp', data = df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
plt.figure(figsize = (12,7))
sns.boxplot(x = 'Pclass', y = 'Age', palette = 'winter', data = df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
#Analyze the Age Distribution of Parameters
sns.histplot(df['Age'],bins = 20,color = 'red')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#Calculate and visualize the correlation between numerical features
correlation = df.corr()
plt.figure(figsize = (15,8))
sns.heatmap(correlation, annot = True, cmap = 'coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#Plottng Pairplot
sns.pairplot(df,hue = 'Survived', palette = 'Set1')
plt.show()

# %%
embark = pd.get_dummies(df['Embarked'],drop_first = True)
sex = pd.get_dummies(df['Sex'],drop_first = True)

# %%
df.drop(['Sex','Embarked','Name','Ticket'], axis = 1, inplace = True)

# %%
df = pd.concat([df,sex,embark],axis = 1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0            1         0       3  22.0      1      0   7.2500     1  0  1
# 1            2         1       1  38.0      1      0  71.2833     0  0  0
# 2            3         1       3  26.0      0      0   7.9250     0  0  1
# 3            4         1       1  35.0      1      0  53.1000     0  0  1
# 4            5         0       3  35.0      0      0   8.0500     1  0  1
